# %% [markdown]
# ## LDU Decomposition
#
# $ \textbf{LU} $ decomposition is not unique when the $ \textbf{L} $ matrix has non-one diagonal entries.
#
# Finding $ \textbf{LU} $ decomposition requires us to perform Gaussian elimination to find the $ \textbf{U} $ matrix, and thus $ \textbf{U} $ will have 1's on the diagonal as well by factoring the diagonal entries out to a diagonal matrix, provided these diagonal entries are non-zero.
#
# $
# \textbf{A} = \textbf{LU} =
# \begin{bmatrix}
# l_{11} & 0 & 0 \\
# l_{21} & l_{22} & 0 \\
# l_{31} & l_{32} & l_{33}
# \end{bmatrix}
# \begin{bmatrix}
# 1 & u_{12} & u_{13} \\
# 0 & 1 & u_{23} \\
# 0 & 0 & 1
# \end{bmatrix}
# $
#
# To make the $ \textbf{LU} $ decomposition unique, we can make $ \textbf{L} $ matrix diagonal elements equal to 1s. We do this by factoring out the diagonal elements into a third diagonal matrix.
#
# $
# \textbf{A} = \textbf{LDU} =
# \begin{bmatrix}
# 1 & 0 & 0 \\
# \frac{l_{21}}{l_{11}} & 1 & 0 \\
# \frac{l_{31}}{l_{11}} & \frac{l_{32}}{l_{22}} & 1
# \end{bmatrix}
# \begin{bmatrix}
# l_{11} & 0 & 0 \\
# 0 & l_{22} & 0 \\
# 0 & 0 & l_{33}
# \end{bmatrix}
# \begin{bmatrix}
# 1 & u_{12} & u_{13} \\
# 0 & 1 & u_{23} \\
# 0 & 0 & 1
# \end{bmatrix}
# $
#
# $
# \Rightarrow \textbf{A} = \textbf{LU}
# \begin{bmatrix}
# 1 & 0 & 0 \\
# \frac{l_{21}}{l_{11}} & 1 & 0 \\
# \frac{l_{31}}{l_{11}} & \frac{l_{32}}{l_{22}} & 1
# \end{bmatrix}
# \begin{bmatrix}
# l_{11} & l_{11}u_{12} & l_{11}u_{13} \\
# 0 & l_{22} & l_{22}u_{23} \\
# 0 & 0 & l_{33}
# \end{bmatrix}
# $
#
# which is unique.

# %% [markdown]
# ### Theorem
#
# If $ \textbf{A} $ is an invertible matrix that can be reduced to row echelon form without row swaps, then $ \textbf{A} $ can be factored uniquely as $ \textbf{A} = \textbf{LDU} $ where $ \textbf{D} $ is a diagonal matrix, and $ \textbf{L} $ and $ \textbf{U} $ are the lower and upper matrices respectively.

# %% [markdown]
# ### Example
#
# Given the following $ \textbf{LU} $ decomposition, find the $ \textbf{LDU} $ decomposition to make it unique.
#
# $
# \textbf{A} = \textbf{LU} =
# \begin{bmatrix}
# 2 & -4 & 1 \\
# 4 & 1 & 5 \\
# 1 & 1 & 2
# \end{bmatrix}
#     =
# \begin{bmatrix}
# 2 & 0 & 0 \\
# 4 & 9 & 0 \\
# 1 & 3 & \frac{1}{2}
# \end{bmatrix}
# \begin{bmatrix}
# 1 & -2 & \frac{1}{2} \\
# 0 & 1 & \frac{1}{3} \\
# 0 & 0 & 1
# \end{bmatrix}
# $
#
# **Solution:**
#
# Factor the diagonal elements of the $ \textbf{L} $ matrix
#
# $
# \textbf{A} = \textbf{LDU} =
# \begin{bmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# \frac{1}{2} & \frac{1}{3} & 1
# \end{bmatrix}
# \begin{bmatrix}
# 2 & 0 & 0 \\
# 0 & 9 & 0 \\
# 0 & 0 & \frac{1}{2}
# \end{bmatrix}
# \begin{bmatrix}
# 1 & -2 & \frac{1}{2} \\
# 0 & 1 & \frac{1}{3} \\
# 0 & 0 & 1
# \end{bmatrix}
# $
#
# This is now a unique decomposition.
